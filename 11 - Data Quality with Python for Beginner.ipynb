# %% [markdown]
# # Apa itu Data Profiling?
#
# Pada bagian sebelumnya, aku sudah mempelajari mengenai exploratory data analysis, dimana Exploratory Data Analysis (EDA) adalah menggunakan pendekatan statistik yang bertujuan untuk menemukan dan meringkas sebuah dataset, mengetahui struktur dan hubungan antar variabel dalam dataset. EDA merupakan proses pre-analysis baik untuk descriptive analysis maupun predictive analysis.
#
# Dalam bab ini, aku akan fokus pada satu aspek EDA, yaitu: Data Profiling!
#
# Data profiling adalah kegiatan merangkum dataset menggunakan statistik deskriptif. Tujuan dari pembuatan data profiling adalah untuk memiliki pemahaman yang kuat tentang data sehingga dapat mulai menyusun framework analisis  dan memvisualisasikan data.
#
# <img src="pic/data_profiling.png" height='400'>

# %%
import pandas as pd
import numpy as np
import io
import ydata_profiling
retail_raw = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/retail_raw_reduced_data_quality.csv')
retail_raw.head()
# Out:
#    order_id  order_date  customer_id             city     province product_id  \
# 0   1703458  17/10/2019        14004  Jakarta Selatan  DKI Jakarta      P1910
# 1   1706815  24/10/2019        17220  Jakarta Selatan  DKI Jakarta      P2934
# 2   1710718  03/11/2019        16518    Jakarta Utara  DKI Jakarta      P0908
# 3   1683592  19/08/2019        16364    Jakarta Barat  DKI Jakarta      P0128
# 4   1702573  16/10/2019        15696    Jakarta Timur  DKI Jakarta      P2968
#
#      brand  quantity  item_price
# 0  BRAND_J      10.0    740000.0
# 1  BRAND_R       2.0    604000.0
# 2  BRAND_C       8.0   1045000.0
# 3  BRAND_A       4.0    205000.0
# 4  BRAND_R       2.0         NaN

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.1.0-py2.py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.9/344.9 kB 2.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (1.9.1)
# Collecting statsmodels<0.14,>=0.13.2
#   Downloading statsmodels-0.13.5-cp38-cp38-macosx_10_9_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 3.6 MB/s eta 0:00:0000:0100:01
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (3.1.2)
# Collecting scipy<1.10,>=1.4.1
#   Downloading scipy-1.9.3-cp38-cp38-macosx_10_9_x86_64.whl (34.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 3.3 MB/s eta 0:00:0000:0100:01
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (2.28.1)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (3.5.2)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 2.0 MB/s eta 0:00:0000:01
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (1.4.3)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from ydata-profiling) (1.23.1)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp38-cp38-macosx_10_13_x86_64.whl (652 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.9/652.9 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm<4.65,>=4.48.2
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pillow in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from imagehash==4.3.1->ydata-profiling) (9.2.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp38-cp38-macosx_10_13_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 3.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: attrs>=19.3.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (21.4.0)
# Collecting networkx>=2.4
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling) (2022.1)
# Collecting joblib>=0.14.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (2022.6.15)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six in /Users/zheva/opt/anaconda3/envs/ML_Binar/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=852fa00020a319d99e62176f1aff8ead963442d0eaa76ac58ae835d7b2a7805a
#   Stored in directory: /Users/zheva/Library/Caches/pip/wheels/23/14/6e/4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tqdm, tangled-up-in-unicode, scipy, PyWavelets, patsy, networkx, multimethod, joblib, imagehash, visions, statsmodels, phik, ydata-profiling
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed PyWavelets-1.4.1 htmlmin-0.1.12 imagehash-4.3.1 joblib-1.2.0 multimethod-1.9.1 networkx-3.0 patsy-0.5.3 phik-0.12.3 scipy-1.9.3 statsmodels-0.13.5 tangled-up-in-unicode-0.2.0 tqdm-4.64.1 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.1.0
